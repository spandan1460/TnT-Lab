# %%
# %matplotlib inline 
# Specific to Jupyter Notebooks

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# df = pd.read_csv('https://raw.githubusercontent.com/mGalarnyk/Python_Tutorials/master/Kaggle/BreastCancerWisconsin/data/data.csv')

# %%
df = pd.read_csv('CardioGoodFitness.csv')

# %%
print('Step 1 : Reading the Data lightly :', df.head(), sep = '\n')
print('--------------------------------------------------------------------\n')
print('Step 2 : Getting No of Rows and Column : ', df.shape)
# Out:
# Step 1 : Reading the Data lightly :
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47
# --------------------------------------------------------------------
#
# Step 2 : Getting No of Rows and Column :  (180, 9)

# %% [markdown]
# STEP 3 : Know the columns and their corresponding data types,along with finding whether they contain null values or not.

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
# Product          180 non-null object
# Age              180 non-null int64
# Gender           180 non-null object
# Education        180 non-null int64
# MaritalStatus    180 non-null object
# Usage            180 non-null int64
# Fitness          180 non-null int64
# Income           180 non-null int64
# Miles            180 non-null int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB
# None

# %% [raw]
# The describe() function in pandas is very handy in getting various summary statistics.This function returns the count, mean, standard deviation, minimum and maximum values and the quantiles of the data.

# %%
df.describe() # Describes the numberical attribute in the Data
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
df['Product'].unique()
# Out:
# array(['TM195', 'TM498', 'TM798'], dtype=object)

# %% [markdown]
# Identifying Number and Unique Values in Categorcial Attributes (Idenitfy number of classes present)

# %%
obj_Attr = ['Product','Gender', 'MaritalStatus']
for i in obj_Attr:
    print(i,' has',df[i].unique(), 'total ',len(df[i].unique()), ' unique values')
# Out:
# Product  has ['TM195' 'TM498' 'TM798'] total  3  unique values
# Gender  has ['Male' 'Female'] total  2  unique values
# MaritalStatus  has ['Single' 'Partnered'] total  2  unique values

# %% [raw]
# Finding the Distribution of the Values in Categorical Attributes

# %%
for i in obj_Attr:
    print(i ,': distribution \n', df[i].value_counts(), '\n------------------------------------------\n')
# Out:
# Product : distribution
#  TM195    80
# TM498    60
# TM798    40
# Name: Product, dtype: int64
# ------------------------------------------
#
# Gender : distribution
#  Male      104
# Female     76
# Name: Gender, dtype: int64
# ------------------------------------------
#
# MaritalStatus : distribution
#  Partnered    107
# Single        73
# Name: MaritalStatus, dtype: int64
# ------------------------------------------

# %% [markdown]
# FINDING THE CORRELATION

# %%
print('The correlation for the numerical data :: \n','---------------------------------------\n',df.corr())
print('---------------------------------------------------------------------------------')
# Out:
# The correlation for the numerical data ::
#  ---------------------------------------
#                  Age  Education     Usage   Fitness    Income     Miles
# Age        1.000000   0.280496  0.015064  0.061105  0.513414  0.036618
# Education  0.280496   1.000000  0.395155  0.410581  0.625827  0.307284
# Usage      0.015064   0.395155  1.000000  0.668606  0.519537  0.759130
# Fitness    0.061105   0.410581  0.668606  1.000000  0.535005  0.785702
# Income     0.513414   0.625827  0.519537  0.535005  1.000000  0.543473
# Miles      0.036618   0.307284  0.759130  0.785702  0.543473  1.000000
# ---------------------------------------------------------------------------------

# %% [markdown]
# PLOTTING THE CORRELATION MATRIX

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.corr())

# %%
for i in df.columns:
    if i in obj_Attr:
        continue
    else:
        sns.boxplot(x = i, data = pd.DataFrame(df[i]))
        plt.show()
        sns.distplot(pd.DataFrame(df[i]), kde = True)
        plt.show()

# %%
# LOADING THE DATA
from sklearn.datasets import load_breast_cancer
data = load_breast_cancer()
data.target[[10, 50, 85]]

list(data.target_names)
# Out:
# ['malignant', 'benign']

# %% [markdown]
# PLOTTING THE BOX PLOT

# %%
import seaborn as sns
sns.boxplot(x='Age', y='Miles', data=df)

# %% [markdown]
# PAIRPLOT

# %%
sns.pairplot(df)

# %%
df.mean()
# Out:
# Age             28.788889
# Education       15.572222
# Usage            3.455556
# Fitness          3.311111
# Income       53719.577778
# Miles          103.194444
# dtype: float64

# %%
df.std()
# Out:
# Age              6.943498
# Education        1.617055
# Usage            1.084797
# Fitness          0.958869
# Income       16506.684226
# Miles           51.863605
# dtype: float64

# %%
df.hist(by = 'Gender', column = 'Income')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000216B434C1C8>,
# ...
#       dtype=object)

# %%
sns.distplot(df['Age'])

# %%
df.hist(by = 'Product', column = 'Miles', figsize = (20, 30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000216B5A3E548>,
# ...
#       dtype=object)
